# %% [markdown]
# # Transforming
#
# In this notebook, we will explore how to use Large Language Models for text transformation tasks such as language translation, spelling and grammar checking, tone adjustment, and format conversion.
#
# ## Setup

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata

api_key = userdata.get('gemini-api-key')
genai.configure(api_key=api_key)

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

def get_completion(prompt):
    response = model.generate_content(prompt)
    return response.text

# %% [markdown]
# ## Translation
#
# ChatGPT is trained with sources in many languages. This gives the model the ability to do translation. Here are some examples of how to use this capability.

# %%
prompt = f"""
Translate the following English text to Spanish: \
```Hi, I would like to order a blender```
"""
response = get_completion(prompt)
print(response)
# Out:
# Hola, me gustaría pedir una licuadora.

# %%
prompt = f"""
Tell me which language this is:
```Combien coûte le lampadaire?```
"""
response = get_completion(prompt)
print(response)
# Out:
# That is **French**.
#
# It means "How much does the streetlight/floor lamp cost?"

# %%
prompt = f"""
Translate the following  text to French and Spanish
and English pirate: \
```I want to order a basketball```
"""
response = get_completion(prompt)
print(response)
# Out:
# Here are the translations:
#
# **Original Text:** I want to order a basketball
#
# ---
#
# **French:**
# Je veux commander un ballon de basket.
#
# ---
#
# **Spanish:**
# Quiero pedir un balón de baloncesto.
#
# ---
#
# **English Pirate:**
# Aarrr! I be wantin' to lay me hands upon a basketball, me hearty!

# %%
prompt = f"""
Translate the following text to Spanish in both the \
formal and informal forms:
'Would you like to order a pillow?'
"""
response = get_completion(prompt)
print(response)
# Out:
# Here are the translations of "Would you like to order a pillow?" in both formal and informal Spanish:
#
# **1. Formal (usted/ustedes)**
#
# *   **¿Le gustaría pedir una almohada?**
#     *   (This is the most common and natural way to express it politely to one or more people you address formally.)
# *   *Slightly more formal/literary:* **¿Desearía pedir una almohada?**
#
# **2. Informal (tú)**
#
# *   **¿Te gustaría pedir una almohada?**
#     *   (This is the most common and polite way to express it to a single person you address informally.)
# *   *More direct informal:* **¿Quieres pedir una almohada?**
#     *   (This is also very common in casual settings, though slightly less polite than using "gustaría.")

# %% [markdown]
# ### Universal Translator
# Imagine you are in charge of IT at a large multinational e-commerce company. Users are messaging you with IT issues in all their native languages. Your staff is from all over the world and speaks only their native languages. You need a universal translator!

# %%
user_messages = [
  "La performance du système est plus lente que d'habitude.",  # System performance is slower than normal
  "Mi monitor tiene píxeles que no se iluminan.",              # My monitor has pixels that are not lighting
  "Il mio mouse non funziona",                                 # My mouse is not working
  "Mój klawisz Ctrl jest zepsuty",                             # My keyboard has a broken control key
  "我的屏幕在闪烁"                                               # My screen is flashing
]

# %%
for issue in user_messages:
    prompt = f"Tell me what language this is: ```{issue}```"
    lang = get_completion(prompt)
    print(f"Original message ({lang}): {issue}")

    prompt = f"""
    Translate the following  text to English \
    and Korean: ```{issue}```
    """
    response = get_completion(prompt)
    print(response, "\n")
# Out:
# Original message (This is **French**.
#
# The English translation is: "The system's performance is slower than usual."): La performance du système est plus lente que d'habitude.
# Here's the translation of "La performance du système est plus lente que d'habitude."
#
# **English:**
# The system performance is slower than usual.
#
# **Korean:**
# 시스템 성능이 평소보다 느려졌습니다.
# (Alternatively, a slightly less formal but equally common: 시스템 성능이 평소보다 느려요.)
#
# Original message (This language is **Spanish**.): Mi monitor tiene píxeles que no se iluminan.
# Here's the translation of "Mi monitor tiene píxeles que no se iluminan" into English and Korean:
#
# **English:**
# *   My monitor has pixels that don't light up.
# *   (More commonly, in technical terms): My monitor has dead pixels.
#
# **Korean:**
# *   **Literal:** 제 모니터에는 불이 들어오지 않는 픽셀이 있어요. (Je moniteoeneun buri deureooji anneun pikseri isseoyo.)
# *   **Common/Technical:** 제 모니터에 죽은 픽셀이 있어요. (Je moniteo-e jugeun pikseri isseoyo.)
# *   **Another common technical term:** 제 모니터에 불량 픽셀이 있어요. (Je moniteo-e bullyang pikseri isseoyo.)
#
# Original message (That language is **Italian**.
#
# The phrase "Il mio mouse non funziona" translates to "My mouse doesn't work".): Il mio mouse non funziona
# **English:** My mouse doesn't work.
#
# **Korean:**
# *   내 마우스가 작동하지 않아요. (Nae ma-u-seu-ga jak-dong-ha-ji a-na-yo.) - *This is a direct and grammatically correct translation.*
# *   내 마우스가 안 돼요. (Nae ma-u-seu-ga an doe-yo.) - *This is a very common and natural way to say "it doesn't work" for a device.*
# *   내 마우스가 고장 났어요. (Nae ma-u-seu-ga go-jang nat-sseo-yo.) - *This means "My mouse is broken," which is often implied when something "doesn't work."*
#
# Original message (This is **Polish**.
#
# The phrase "Mój klawisz Ctrl jest zepsuty" translates to "My Ctrl key is broken."): Mój klawisz Ctrl jest zepsuty
# Here are the translations:
#
# **English:**
# My Ctrl key is broken.
#
# **Korean:**
# 내 컨트롤 키가 고장 났어요.
#
# Original message (This is **Chinese**.
#
# Specifically, it is **Simplified Chinese**.
#
# It translates to: "My screen is flickering."): 我的屏幕在闪烁
# **English:**
# My screen is flickering.
#
# **Korean:**
# 내 화면이 깜빡거려요. (Informal polite)
# 저의 화면이 깜빡거리고 있습니다. (Formal polite)

# %% [markdown]
# ## Try it yourself!
# Try some translations on your own!

# %% [markdown]
# ## Tone Transformation
# Writing can vary based on the intended audience. ChatGPT can produce different tones.

# %%
prompt = f"""
Translate the following from slang to a business letter:
'Dude, This is Joe, check out this spec on this standing lamp.'
"""
response = get_completion(prompt)
print(response)
# Out:
# Here are a few options, ranging from a slightly less formal business email/memo style to a more formal business letter, depending on the recipient and context:
#
# ---
#
# **Option 1: Professional Email/Internal Memo Style (Most likely for this scenario)**
#
# **Subject:** Review of Specifications for Standing Lamp - [Product Model/Project Name, if applicable]
#
# Dear [Recipient Name or Team Name, e.g., "Engineering Team," "Procurement Department"],
#
# Please find attached for your review the detailed specifications for the standing lamp.
#
# Your prompt review and feedback on these specifications would be greatly appreciated as we move forward with this project.
#
# Should you have any questions or require further clarification, please do not hesitate to contact me.
#
# Thank you for your time and attention to this matter.
#
# Sincerely,
#
# Joe [Last Name]
# [Your Title, e.g., Product Manager, Design Engineer]
# [Your Department/Company]
#
# ---
#
# **Option 2: More Formal Business Letter Style**
#
# [Your Name]
# [Your Title]
# [Your Company Name]
# [Your Company Address]
# [Your Phone Number]
# [Your Email Address]
#
# [Date]
#
# [Recipient Name]
# [Recipient Title]
# [Recipient Company Name]
# [Recipient Company Address]
#
# **Subject: Submission of Technical Specifications for Standing Lamp**
#
# Dear [Mr./Ms./Mx. Last Name of Recipient],
#
# I am pleased to provide you with the comprehensive technical specifications for the standing lamp, attached for your detailed review.
#
# We request your thorough evaluation of these specifications and welcome any insights or feedback you may have. Your expertise is invaluable to ensuring the successful development and implementation of this product.
#
# Please feel free to reach out to me directly should you require any additional information or clarification.
#
# Thank you for your consideration of this matter.
#
# Sincerely,
#
# [Signature]
#
# Joe [Last Name]
# [Your Typed Title]
#
# ---
#
# **Key Changes and Why:**
#
# *   **"Dude"**: Replaced with a formal salutation ("Dear [Name]").
# *   **"This is Joe"**: Your name and title are provided in the closing signature. The letter itself establishes you as the sender.
# *   **"check out"**: Replaced with formal requests like "Please find attached for your review," "Your prompt review and feedback are appreciated," or "I am pleased to provide you with."
# *   **"this spec"**: Clarified to "detailed specifications," "technical specifications," or "comprehensive technical specifications."
# *   **"on this standing lamp"**: More formally phrased as "for the standing lamp" or "pertaining to the standing lamp."
# *   **Structure**: Added a clear subject line, formal salutation, body paragraphs stating the purpose and call to action, and a professional closing.
# *   **Tone**: Shifted from casual and imperative to polite, professional, and collaborative.

# %% [markdown]
# ## Format Conversion
# ChatGPT can translate between formats. The prompt should describe the input and output formats.

# %%
data_json = { "resturant employees" :[
    {"name":"Shyam", "email":"shyamjaiswal@gmail.com"},
    {"name":"Bob", "email":"bob32@gmail.com"},
    {"name":"Jai", "email":"jai87@gmail.com"}
]}

prompt = f"""
Translate the following python dictionary from JSON to an HTML \
table with column headers and title: {data_json}
"""
response = get_completion(prompt)
print(response)
# Out:
# ```html
# <table border="1" style="width:100%; border-collapse: collapse; margin-top: 20px;">
#     <caption>
#         <h2 style="margin-bottom: 10px;">Restaurant Employees</h2>
#     </caption>
#     <thead>
#         <tr style="background-color: #f2f2f2;">
#             <th style="padding: 10px; border: 1px solid #ddd; text-align: left;">Name</th>
#             <th style="padding: 10px; border: 1px solid #ddd; text-align: left;">Email</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="padding: 10px; border: 1px solid #ddd;">Shyam</td>
#             <td style="padding: 10px; border: 1px solid #ddd;">shyamjaiswal@gmail.com</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px; border: 1px solid #ddd;">Bob</td>
#             <td style="padding: 10px; border: 1px solid #ddd;">bob32@gmail.com</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px; border: 1px solid #ddd;">Jai</td>
#             <td style="padding: 10px; border: 1px solid #ddd;">jai87@gmail.com</td>
#         </tr>
#     </tbody>
# </table>
# ```

# %%
from IPython.display import display, Markdown, Latex, HTML, JSON
display(HTML(response))
# Out:
# ```html
# <table border="1" style="width:100%; border-collapse: collapse; margin-top: 20px;">
#     <caption>
#         <h2 style="margin-bottom: 10px;">Restaurant Employees</h2>
#     </caption>
#     <thead>
#         <tr style="background-color: #f2f2f2;">
#             <th style="padding: 10px; border: 1px solid #ddd; text-align: left;">Name</th>
#             <th style="padding: 10px; border: 1px solid #ddd; text-align: left;">Email</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="padding: 10px; border: 1px solid #ddd;">Shyam</td>
#             <td style="padding: 10px; border: 1px solid #ddd;">shyamjaiswal@gmail.com</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px; border: 1px solid #ddd;">Bob</td>
#             <td style="padding: 10px; border: 1px solid #ddd;">bob32@gmail.com</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px; border: 1px solid #ddd;">Jai</td>
#             <td style="padding: 10px; border: 1px solid #ddd;">jai87@gmail.com</td>
#         </tr>
#     </tbody>
# </table>
# ```

# %% [markdown]
# ## Spellcheck/Grammar check.
#
# Here are some examples of common grammar and spelling problems and the LLM's response.
#
# To signal to the LLM that you want it to proofread your text, you instruct the model to 'proofread' or 'proofread and correct'.

# %%
text = [
  "The girl with the black and white puppies have a ball.",  # The girl has a ball.
  "Yolanda has her notebook.", # ok
  "Its going to be a long day. Does the car need it’s oil changed?",  # Homonyms
  "Their goes my freedom. There going to bring they’re suitcases.",  # Homonyms
  "Your going to need you’re notebook.",  # Homonyms
  "That medicine effects my ability to sleep. Have you heard of the butterfly affect?", # Homonyms
  "This phrase is to cherck chatGPT for speling abilitty"  # spelling
]
for t in text:
    prompt = f"""Proofread and correct the following text
    and rewrite the corrected version. If you don't find
    and errors, just say "No errors found". Don't use
    any punctuation around the text:
    ```{t}```"""
    response = get_completion(prompt)
    print(response)
# Out:
# The girl with the black and white puppies has a ball.
# No errors found
# It's going to be a long day. Does the car need its oil changed?
# There goes my freedom. They're going to bring their suitcases.
# You're going to need your notebook.
# That medicine affects my ability to sleep. Have you heard of the butterfly effect?
# This phrase is to check ChatGPT for spelling ability

# %%
text = f"""
Got this for my daughter for her birthday cuz she keeps taking \
mine from my room.  Yes, adults also like pandas too.  She takes \
it everywhere with her, and it's super soft and cute.  One of the \
ears is a bit lower than the other, and I don't think that was \
designed to be asymmetrical. It's a bit small for what I paid for it \
though. I think there might be other options that are bigger for \
the same price.  It arrived a day earlier than expected, so I got \
to play with it myself before I gave it to my daughter.
"""
prompt = f"proofread and correct this review: ```{text}```"
response = get_completion(prompt)
print(response)
# Out:
# Here's a revised version of your review, focusing on clarity, grammar, and a slightly more polished tone while retaining your original voice:
#
# **Option 1 (Slightly More Formal):**
#
# > I purchased this for my daughter's birthday because she kept taking mine from my room. (For the record, adults like pandas too!) She takes it everywhere with her; it's incredibly soft and cute. However, one of the ears is slightly lower than the other, and I don't believe this was an intentional design choice for asymmetry. It's a bit smaller than I expected for its price point, and I suspect there may be larger options available for the same cost. On a positive note, it arrived a day earlier than expected, which gave me a chance to "play" with it myself before giving it to my daughter!
#
# **Option 2 (Keeping it a bit more casual, closer to original tone):**
#
# > I got this for my daughter's birthday because she keeps taking mine from my room. (And yes, adults like pandas too!) She takes it everywhere with her, and it's super soft and cute. One of the ears is a bit lower than the other, and I don't think that was designed to be asymmetrical. It's a little small for what I paid for it, though. I think there might be other options that are bigger for the same price. It arrived a day earlier than expected, so I got to play with it myself before I gave it to my daughter!
#
# **Key Changes and Why:**
#
# *   **"cuz" to "because"**: More appropriate for a written review.
# *   **"adults also like pandas too"**: Redundant "also" and "too." I rephrased it to be more direct and added a touch of humor/parenthetical.
# *   **"super soft and cute"**: "Incredibly soft and cute" or "very soft and cute" sounds slightly more refined, but "super" is common in reviews and fine. I offered both.
# *   **"One of the ears is a bit lower..."**: Added "However" or just kept the flow, signalling a shift to a minor negative point. "Slightly lower" is a good substitute for "a bit lower."
# *   **"I don't think that was designed to be asymmetrical"**: Rephrased for clarity: "I don't believe this was an intentional design choice for asymmetry."
# *   **"a bit small for what I paid for it though"**: Rephrased to "a bit smaller than I expected for its price point" or "a little small for what I paid for it." Both are clearer.
# *   **"I think there might be other options that are bigger"**: Changed "bigger" to "larger" for a slightly more formal tone, and "I suspect there may be" or "I think there might be" are both fine.
# *   **"so I got to play with it myself"**: Added quotation marks around "play" to acknowledge the humor, and an exclamation mark for warmth.
#
# Choose the option that best fits the overall tone you want for your review!

# %%
# !pip install redlines
# Out:
# Collecting redlines
#   Downloading redlines-0.5.2-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from redlines) (8.2.1)
# Collecting rich-click>=1.6.1 (from redlines)
#   Downloading rich_click-1.8.9-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: rich>=13.3.5 in /usr/local/lib/python3.11/dist-packages (from redlines) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.3.5->redlines) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.3.5->redlines) (2.19.1)
# Requirement already satisfied: typing_extensions>=4 in /usr/local/lib/python3.11/dist-packages (from rich-click>=1.6.1->redlines) (4.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.5->redlines) (0.1.2)
# Downloading redlines-0.5.2-py3-none-any.whl (12 kB)
# Downloading rich_click-1.8.9-py3-none-any.whl (36 kB)
# Installing collected packages: rich-click, redlines
# Successfully installed redlines-0.5.2 rich-click-1.8.9

# %%
from redlines import Redlines

diff = Redlines(text,response)
display(Markdown(diff.output_markdown))
# Out:
# <span style='color:red;font-weight:700;text-decoration:line-through;'>Got </span><span style='color:green;font-weight:700;'>Here's a revised version of your review, focusing on clarity, grammar, and a slightly more polished tone while retaining your original voice: </span>
#
# <span style='color:green;font-weight:700;'>**Option 1 (Slightly More Formal):** </span>
#
# <span style='color:green;font-weight:700;'>> I purchased </span>this for my <span style='color:red;font-weight:700;text-decoration:line-through;'>daughter for her </span><span style='color:green;font-weight:700;'>daughter's </span>birthday <span style='color:red;font-weight:700;text-decoration:line-through;'>cuz </span><span style='color:green;font-weight:700;'>because she kept taking mine from my room. (For the record, adults like pandas too!) She takes it everywhere with her; it's incredibly soft and cute. However, one of the ears is slightly lower than the other, and I don't believe this was an intentional design choice for asymmetry. It's a bit smaller than I expected for its price point, and I suspect there may be larger options available for the same cost. On a positive note, it arrived a day earlier than expected, which gave me a chance to "play" with it myself before giving it to my daughter! </span>
#
# <span style='color:green;font-weight:700;'>**Option 2 (Keeping it a bit more casual, closer to original tone):** </span>
#
# <span style='color:green;font-weight:700;'>> I got this for my daughter's birthday because </span>she keeps taking mine from my room.  <span style='color:red;font-weight:700;text-decoration:line-through;'>Yes, </span><span style='color:green;font-weight:700;'>(And yes, </span>adults <span style='color:red;font-weight:700;text-decoration:line-through;'>also </span>like pandas <span style='color:red;font-weight:700;text-decoration:line-through;'>too.  </span><span style='color:green;font-weight:700;'>too!) </span>She takes it everywhere with her, and it's super soft and cute.  One of the ears is a bit lower than the other, and I don't think that was designed to be asymmetrical. It's a <span style='color:red;font-weight:700;text-decoration:line-through;'>bit </span><span style='color:green;font-weight:700;'>little </span>small for what I paid for <span style='color:red;font-weight:700;text-decoration:line-through;'>it </span><span style='color:green;font-weight:700;'>it, </span>though. I think there might be other options that are bigger for the same price.  It arrived a day earlier than expected, so I got to play with it myself before I gave it to my <span style='color:red;font-weight:700;text-decoration:line-through;'>daughter.</span><span style='color:green;font-weight:700;'>daughter! </span>
#
# <span style='color:green;font-weight:700;'>**Key Changes and Why:** </span>
#
# <span style='color:green;font-weight:700;'>*   **"cuz" to "because"**: More appropriate for a written review. </span>
#
# <span style='color:green;font-weight:700;'>*   **"adults also like pandas too"**: Redundant "also" and "too." I rephrased it to be more direct and added a touch of humor/parenthetical. </span>
#
# <span style='color:green;font-weight:700;'>*   **"super soft and cute"**: "Incredibly soft and cute" or "very soft and cute" sounds slightly more refined, but "super" is common in reviews and fine. I offered both. </span>
#
# <span style='color:green;font-weight:700;'>*   **"One of the ears is a bit lower..."**: Added "However" or just kept the flow, signalling a shift to a minor negative point. "Slightly lower" is a good substitute for "a bit lower." </span>
#
# <span style='color:green;font-weight:700;'>*   **"I don't think that was designed to be asymmetrical"**: Rephrased for clarity: "I don't believe this was an intentional design choice for asymmetry." </span>
#
# <span style='color:green;font-weight:700;'>*   **"a bit small for what I paid for it though"**: Rephrased to "a bit smaller than I expected for its price point" or "a little small for what I paid for it." Both are clearer. </span>
#
# <span style='color:green;font-weight:700;'>*   **"I think there might be other options that are bigger"**: Changed "bigger" to "larger" for a slightly more formal tone, and "I suspect there may be" or "I think there might be" are both fine. </span>
#
# <span style='color:green;font-weight:700;'>*   **"so I got to play with it myself"**: Added quotation marks around "play" to acknowledge the humor, and an exclamation mark for warmth. </span>
#
# <span style='color:green;font-weight:700;'>Choose the option that best fits the overall tone you want for your review!</span>

# %%
prompt = f"""
proofread and correct this review. Make it more compelling.
Ensure it follows APA style guide and targets an advanced reader.
Output in markdown format.
Text: ```{text}```
"""
response = get_completion(prompt)
display(Markdown(response))
# Out:
# Here's a revised version of your review, adhering to APA style conventions (primarily in tone, precision, and formality, as direct citations aren't applicable here), targeting an advanced reader, and enhanced for compellingness.
#
# ---
#
# ### Evaluation of a Plush Collectible: A Critical Assessment
#
# This plush collectible was acquired for a recent birthday, primarily necessitated by the recipient's persistent appropriation of my own personal items of a similar nature. It is pertinent to note that the enduring appeal of anthropomorphic panda iconography extends beyond purely juvenile demographics.
#
# Upon presentation, the item was immediately adopted by my daughter, who now carries it ubiquitously. Its primary attributes are its exceptional tactile softness and an undeniably charming aesthetic. These qualities contribute significantly to its high user engagement and perceived value by the intended recipient.
#
# However, a noticeable manufacturing inconsistency is present: one ear is positioned demonstrably lower than the other, suggesting an unintended asymmetry rather than a deliberate design choice. Furthermore, a notable concern pertains to its diminutive size relative to its cost; preliminary market analysis suggests more substantial options may be available at a comparable price point, potentially offering a more favorable size-to-cost ratio for discerning consumers.
#
# A significant positive aspect of this acquisition was the expedited delivery, which occurred a full day ahead of the estimated schedule. This early arrival afforded an unexpected opportunity for personal interaction and preliminary assessment prior to gifting, a small but appreciated benefit of the purchasing experience.
#
# In summary, while the plush excels in softness and charm, and its delivery was commendably prompt, the manufacturing inconsistency and the perceived value proposition (size relative to cost) are areas that warrant consideration for future product iterations or consumer choices. Its utility as a beloved comfort item, however, remains undisputed.
#
# ---

# %% [markdown]
# ## Try it yourself!
# Try changing the instructions to form your own review.

# %% [markdown]
# Thanks to the following sites:
#
# https://writingprompts.com/bad-grammar-examples/
