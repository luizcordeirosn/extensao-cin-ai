# %% [markdown]
# # Iterative Prompt Development
# In this lesson, you'll iteratively analyze and refine your prompts to generate marketing copy from a product fact sheet.
#
# ## Setup

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata

api_key = userdata.get('gemini-api-key')
genai.configure(api_key=api_key)

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

def get_completion(prompt):
    response = model.generate_content(prompt)
    return response.text

# %% [markdown]
# **Note**: In June 2023, OpenAI updated gpt-3.5-turbo. The results you see in the notebook may be slightly different than those in the video. Some of the prompts have also been slightly modified to product the desired results.

# %% [markdown]
# ## Generate a marketing product description from a product fact sheet

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture,
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100)
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black,
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities:
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# ## Elevate Your Workspace with Mid-Century Modern Style
#
# Complete your office aesthetic with this stunning chair, a key piece in our family of mid-century inspired office furniture. From filing cabinets to desks and meeting tables, build a cohesive and stylish workspace that reflects your unique taste.
#
# This chair offers unparalleled customization to perfectly match your needs and décor. Choose from several captivating shell colors and base finishes, including stainless steel, matte black, gloss white, and chrome. Select between plastic back and front upholstery (SWC-100) or indulge in the luxurious comfort of full upholstery (SWC-110), available in 10 fabric and 6 leather options. You can also choose to have the chair with or without armrests, based on your comfort preference.
#
# Built for both home and business environments, this chair is qualified for contract use, ensuring durability and longevity. The 5-wheel plastic coated aluminum base provides smooth and stable movement, while the pneumatic chair adjust allows for effortless height adjustments.
#
# **Key Features:**
#
# *   **Mid-Century Modern Design:** Seamlessly integrates with a range of design styles.
# *   **Unparalleled Customization:** Choose from a variety of shell colors, base finishes, upholstery options, and armrest configurations.
# *   **Durable Construction:** Featuring a cast aluminum shell with a modified nylon coating and a robust 5-wheel base.
# *   **Comfortable Seating:** Enjoy ergonomic support with HD36 foam and customizable seat foam densities (medium 1.8 lb/ft3 or high 2.8 lb/ft3).
# *   **Adjustable Height:** Easily raise or lower the chair with the convenient pneumatic adjustment.
# *   **Versatile Use:** Suitable for home offices, corporate spaces, and meeting rooms.
#
# **Dimensions:**
#
# *   Width: 53 cm (20.87”)
# *   Depth: 51 cm (20.08”)
# *   Height: 80 cm (31.50”)
# *   Seat Height: 44 cm (17.32”)
# *   Seat Depth: 41 cm (16.14”)
#
# **Options:**
#
# *   Soft or hard-floor caster options.
# *   Medium (1.8 lb/ft3) or high (2.8 lb/ft3) seat foam density.
# *   Armless or 8 position PU armrests.
#
# **Materials:**
#
# *   Shell: Cast Aluminum with modified nylon PA6/PA66 coating (10 mm thickness).
# *   Base: Cast Aluminum with modified nylon PA6/PA66 coating.
# *   Seat: HD36 foam.
#
# **Crafted in Italy.**
#
# Upgrade your workspace with this stylish and functional chair today!

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# This mid-century modern chair, perfect for home or office, offers customizable shell colors and base finishes. Choose from plastic or full upholstery in various fabrics and leathers. Features a 5-wheel aluminum base, adjustable height, and optional armrests. Made in Italy.

# %%
len(response.split())
# Out:
# 40

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description is intended for furniture retailers,
so should be technical in nature and focus on the
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# This mid-century inspired chair features a cast aluminum shell with a modified nylon PA6/PA66 coating and a 5-wheel plastic coated aluminum base. The seat utilizes HD36 foam. Available with optional armrests and soft or hard-floor casters. Shell thickness: 10mm. Origin: Italy.

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description is intended for furniture retailers,
so should be technical in nature and focus on the
materials the product is constructed from.

At the end of the description, include every 7-character
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# This mid-century inspired chair features a cast aluminum shell with modified nylon PA6/PA66 coating, a 5-wheel plastic coated aluminum base, and HD36 foam seat. Available with multiple base finishes and upholstery options.
#
# SWC-100
# SWC-110

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt = f"""
Your task is to help a marketing team create a
description for a retail website of a product based
on a technical fact sheet.

Write a product description based on the information
provided in the technical specifications delimited by
triple backticks.

The description is intended for furniture retailers,
so should be technical in nature and focus on the
materials the product is constructed from.

At the end of the description, include every 7-character
Product ID in the technical specification.

After the description, include a table that gives the
product's dimensions. The table should have two columns.
In the first column include the name of the dimension.
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website.
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# ```html
# <div>
#   <h2>Technical Product Description</h2>
#   <p>This mid-century inspired office chair is built for both style and durability. The shell is constructed from cast aluminum with a modified nylon PA6/PA66 coating, offering superior strength and a sleek aesthetic. The shell thickness is 10mm ensuring robustness and longevity.</p>
#
#   <p>The chair features a 5-wheel base made from plastic-coated aluminum, providing smooth mobility and stability. The pneumatic height adjustment mechanism allows for easy customization of seat height.</p>
#
#   <p>The seat is composed of HD36 foam for comfortable support. Available in two upholstery options, plastic back and front (SWC-100) or full upholstery (SWC-110), and a range of 10 fabric and 6 leather choices. Base finish options include stainless steel, matte black, gloss white, or chrome, allowing for seamless integration into diverse office environments.</p>
#
#   <p>Additional options include soft or hard-floor casters, two seat foam densities (1.8 lb/ft3 or 2.8 lb/ft3), and armless or 8-position PU armrest configurations.</p>
#
#   <p>Product IDs: SWC-100, SWC-110</p>
# </div>
#
# <h2>Product Dimensions</h2>
# <table>
#   <thead>
#     <tr>
#       <th>Dimension</th>
#       <th>Measurement (Inches)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Width</td>
#       <td>20.87"</td>
#     </tr>
#     <tr>
#       <td>Depth</td>
#       <td>20.08"</td>
#     </tr>
#     <tr>
#       <td>Height</td>
#       <td>31.50"</td>
#     </tr>
#     <tr>
#       <td>Seat Height</td>
#       <td>17.32"</td>
#     </tr>
#     <tr>
#       <td>Seat Depth</td>
#       <td>16.14"</td>
#     </tr>
#   </tbody>
# </table>
# ```

# %% [markdown]
# ## Load Python libraries to view HTML

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
# Out:
# ```html
# <div>
#   <h2>Technical Product Description</h2>
#   <p>This mid-century inspired office chair is built for both style and durability. The shell is constructed from cast aluminum with a modified nylon PA6/PA66 coating, offering superior strength and a sleek aesthetic. The shell thickness is 10mm ensuring robustness and longevity.</p>
#
#   <p>The chair features a 5-wheel base made from plastic-coated aluminum, providing smooth mobility and stability. The pneumatic height adjustment mechanism allows for easy customization of seat height.</p>
#
#   <p>The seat is composed of HD36 foam for comfortable support. Available in two upholstery options, plastic back and front (SWC-100) or full upholstery (SWC-110), and a range of 10 fabric and 6 leather choices. Base finish options include stainless steel, matte black, gloss white, or chrome, allowing for seamless integration into diverse office environments.</p>
#
#   <p>Additional options include soft or hard-floor casters, two seat foam densities (1.8 lb/ft3 or 2.8 lb/ft3), and armless or 8-position PU armrest configurations.</p>
#
#   <p>Product IDs: SWC-100, SWC-110</p>
# </div>
#
# <h2>Product Dimensions</h2>
# <table>
#   <thead>
#     <tr>
#       <th>Dimension</th>
#       <th>Measurement (Inches)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Width</td>
#       <td>20.87"</td>
#     </tr>
#     <tr>
#       <td>Depth</td>
#       <td>20.08"</td>
#     </tr>
#     <tr>
#       <td>Height</td>
#       <td>31.50"</td>
#     </tr>
#     <tr>
#       <td>Seat Height</td>
#       <td>17.32"</td>
#     </tr>
#     <tr>
#       <td>Seat Depth</td>
#       <td>16.14"</td>
#     </tr>
#   </tbody>
# </table>
# ```

# %% [markdown]
# ## Try experimenting on your own!
